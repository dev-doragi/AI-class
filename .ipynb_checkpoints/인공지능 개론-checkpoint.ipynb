# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/Project/Anaconda/breast_cancer.csv", index_col=0)

# %%
# 데이터 확인
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  label
# 0                  0.2654          0.4601                  0.11890      0
# 1                  0.1860          0.2750                  0.08902      0
# 2                  0.2430          0.3613                  0.08758      0
# 3                  0.2575          0.6638                  0.17300      0
# 4                  0.1625          0.2364                  0.07678      0
# ..                    ...             ...                      ...    ...
# 564                0.2216          0.2060                  0.07115      0
# 565                0.1628          0.2572                  0.06637      0
# 566                0.1418          0.2218                  0.07820      0
# 567                0.2650          0.4087                  0.12400      0
# 568                0.0000          0.2871                  0.07039      1
#
# [569 rows x 31 columns]

# %%
# 컬렴명 확인
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'label'],
#       dtype='object')

# %%
# 레이블 갯수 확인 (그래프)
# 여기서 "label"은 유방암의 유무를 나타내는 지표

sns.countplot(data = df, x="label")
plt.xlabel("Cancer or Not")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
# 레이블 갯수 확인 (숫자)
df['label'].value_counts()
# Out:
# 1    357
# 0    212
# Name: label, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
# 머신러닝 알고리즘을 사용하여 결측치를 예측하고 대체할 수 있다.
from sklearn.impute import KNNImputer
imputer = KNNImputer()
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

#df.isnull().sum()

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
# 컬럼별 히스토그램 확인
# 'mean radius'와'mean texture' 칼럼을 선택

figure = plt.figure(figsize=(18,6))
ax1 = plt.subplot(1,2,1)
sns.distplot(df['mean radius'], kde = True, hist = False, ax=ax1)
ax2 = plt.subplot(1,2,2)
sns.distplot(df['mean texture'], ax=ax2)
# Out:
# C:\Anaconda\envs\AI-class\lib\site-packages\ipykernel_launcher.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Anaconda\envs\AI-class\lib\site-packages\ipykernel_launcher.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='mean texture', ylabel='Density'>

# %%
from matplotlib.ticker import FuncFormatter

# 'mean radius'와 'mean texture' 칼럼 선택
selected_columns = ['mean radius', 'mean texture']

# figure 설정
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# 사용자 정의 백분율 형식 함수
def percent_formatter(x, pos):
    return f'{x:.0%}'

# 첫 번째 subplot
sns.histplot(df[selected_columns[0]], kde=True, ax=axes[0])
axes[0].set_title(f'Distribution of {selected_columns[0]}')
axes[0].set_ylabel('Density')  # y축 레이블 설정
axes[0].yaxis.set_major_formatter(FuncFormatter(percent_formatter))  # 백분율 형식으로 설정

# 두 번째 subplot
sns.histplot(df[selected_columns[1]], kde=True, ax=axes[1])
axes[1].set_title(f'Distribution of {selected_columns[1]}')
axes[1].set_ylabel('Density')  # y축 레이블 설정
axes[1].yaxis.set_major_formatter(FuncFormatter(percent_formatter))  # 백분율 형식으로 설정

plt.show()

# %%
# 산점도 확인

plt.scatter(df['mean radius'], df['mean texture'])
plt.xlabel('Mean Radius')
plt.ylabel('Mean Texture')

plt.show()

# %%
# pairplot를 사용해 각 상관관계 살펴보기

sns.pairplot(df,
             vars=['mean radius', 'mean texture', 'mean perimeter', 'mean area'],
            hue ='label')
plt.show()

# %%
# 각 컬럼별 히스토 그램 확인

fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
plt.show()
# Out:
# C:\Anaconda\envs\AI-class\lib\site-packages\ipykernel_launcher.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   """

# %%
X=df.drop('label',axis=1)
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
y=df['label']
y.value_counts()
# Out:
# 1    357
# 0    212
# Name: label, dtype: int64

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.1, 
                                                    shuffle = True, 
                                                    random_state = 21)

# %%
def split_sequences(sequences, n_steps):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# Merge train and test X/y data to apply sequence transformation function
y_train_array = np.array(y_train)
train_set = np.c_[X_train, y_train_array]

y_test_array = np.array(y_test)
test_set = np.c_[X_test, y_test_array]

# Apply sequence transformation using time step of 25 for both train and test data
# All sensing modalities are recorded at a sampling rate of 50 Hz, which is considered sufficient for capturing human activity.

X_train, y_train = split_sequences(train_set, 5)
print(X_train.shape, y_train.shape)

X_test, y_test = split_sequences(test_set, 5)
print(X_test.shape, y_test.shape)
# Out:
# (508, 5, 30) (508,)
# (53, 5, 30) (53,)

# %%
y_train_onehot = pd.get_dummies(y_train).values
y_test_onehot = pd.get_dummies(y_test).values

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Input
from keras.layers import Dense, Flatten, Dropout

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_onehot.shape[1]

# %%
input_layer = Input(shape=(n_timesteps,n_features))

conv1 = Conv1D(filters=64, kernel_size=3, activation='relu')(input_layer) 
flat = Flatten()(conv1)
dens = Dense(64, activation = "relu")(flat)
outputs = Dense(2, activation = "sigmoid")(dens)

model = keras.Model(input_layer, outputs)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 30)]           0
#
#  conv1d (Conv1D)             (None, 3, 64)             5824
#
#  flatten (Flatten)           (None, 192)               0
#
#  dense (Dense)               (None, 64)                12352
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 18,306
# Trainable params: 18,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_epochs = 30
history = model.fit(X_train, y_train_onehot, epochs=train_epochs, verbose=True,  validation_split = 0.1)
# Out:
# Epoch 1/30
# 15/15 [==============================] - 1s 25ms/step - loss: 19.5130 - accuracy: 0.6543 - val_loss: 6.1288 - val_accuracy: 0.5882
# Epoch 2/30
# 15/15 [==============================] - 0s 5ms/step - loss: 4.6922 - accuracy: 0.7856 - val_loss: 2.4866 - val_accuracy: 0.8039
# Epoch 3/30
# 15/15 [==============================] - 0s 5ms/step - loss: 3.1538 - accuracy: 0.8162 - val_loss: 3.0177 - val_accuracy: 0.8039
# Epoch 4/30
# 15/15 [==============================] - 0s 6ms/step - loss: 2.2747 - accuracy: 0.8446 - val_loss: 2.2778 - val_accuracy: 0.8039
# Epoch 5/30
# 15/15 [==============================] - 0s 6ms/step - loss: 1.3773 - accuracy: 0.8512 - val_loss: 1.3263 - val_accuracy: 0.8431
# Epoch 6/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.6233 - accuracy: 0.8578 - val_loss: 1.2535 - val_accuracy: 0.8039
# Epoch 7/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.5314 - accuracy: 0.8709 - val_loss: 0.4677 - val_accuracy: 0.9412
# Epoch 8/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.2323 - accuracy: 0.8796 - val_loss: 0.9332 - val_accuracy: 0.8824
# Epoch 9/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.0995 - accuracy: 0.8862 - val_loss: 2.0495 - val_accuracy: 0.7843
# Epoch 10/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.8680 - accuracy: 0.8687 - val_loss: 0.3170 - val_accuracy: 0.9804
# Epoch 11/30
# 15/15 [==============================] - 0s 4ms/step - loss: 2.1353 - accuracy: 0.8315 - val_loss: 1.4230 - val_accuracy: 0.8431
# Epoch 12/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.4783 - accuracy: 0.8687 - val_loss: 0.4845 - val_accuracy: 0.9020
# Epoch 13/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.3927 - accuracy: 0.8818 - val_loss: 0.4277 - val_accuracy: 0.9216
# Epoch 14/30
# 15/15 [==============================] - 0s 4ms/step - loss: 2.6055 - accuracy: 0.7987 - val_loss: 1.5717 - val_accuracy: 0.8235
# Epoch 15/30
# 15/15 [==============================] - 0s 4ms/step - loss: 1.5108 - accuracy: 0.8753 - val_loss: 0.5088 - val_accuracy: 0.9608
# Epoch 16/30
# 15/15 [==============================] - 0s 5ms/step - loss: 1.1175 - accuracy: 0.8928 - val_loss: 0.1282 - val_accuracy: 0.9804
# Epoch 17/30
# 15/15 [==============================] - 0s 4ms/step - loss: 0.7662 - accuracy: 0.9125 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 18/30
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.9278 - val_loss: 0.4113 - val_accuracy: 0.9804
# Epoch 19/30
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6434 - accuracy: 0.9190 - val_loss: 0.9450 - val_accuracy: 0.9804
# Epoch 20/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5862 - accuracy: 0.9190 - val_loss: 1.5773 - val_accuracy: 0.7647
# Epoch 21/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.9147 - val_loss: 0.4558 - val_accuracy: 0.9412
# Epoch 22/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4709 - accuracy: 0.9256 - val_loss: 0.3004 - val_accuracy: 0.9216
# Epoch 23/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3715 - accuracy: 0.9387 - val_loss: 0.4506 - val_accuracy: 0.9020
# Epoch 24/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4585 - accuracy: 0.9300 - val_loss: 0.1859 - val_accuracy: 0.9804
# Epoch 25/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.8793 - accuracy: 0.8862 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 26/30
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4836 - accuracy: 0.9300 - val_loss: 0.3921 - val_accuracy: 0.9216
# Epoch 27/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4455 - accuracy: 0.9256 - val_loss: 0.6148 - val_accuracy: 0.8824
# Epoch 28/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5389 - accuracy: 0.9125 - val_loss: 0.6482 - val_accuracy: 0.9216
# Epoch 29/30
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4615 - accuracy: 0.9322 - val_loss: 0.7494 - val_accuracy: 0.9020
# Epoch 30/30
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.9059 - val_loss: 0.4900 - val_accuracy: 0.9412

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix


y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test_onehot,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# KeyboardInterrupt

# %%
from sklearn.linear_model import LogisticRegression

# 입력과 출력 데이터 생성
features = [[1], [2], [3], [4]]
labels = [0, 0, 1, 1]

# 모델 학습
classification_model = LogisticRegression()
classification_model.fit(features, labels)

# 예측
new_data = [[5]]
predicted_label = classification_model.predict(new_data)

# 디버깅 출력
print("Logistic Regression 예측 결과:", predicted_label)
