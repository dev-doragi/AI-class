# %% [markdown]
# 머신러닝 실습
# 1. 데이터 읽기
# 2. 결측치 확인
# 3. 클래스 개수 확인 (그래프, 레이블 개수)
# 4. StandardScale 사용
# 5. 필요한 경우 Encoding
# 6. 함수형 모델 사용 함수형 API
# 7. ML/DL Regression 각각
# 8. Github 업로드

# %% [markdown]
# ### ML-Classification 전복 성별 분류

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv("./abalone.data", header=None)
df.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="Rings")
plt.xlabel("Rings")
plt.ylabel("Count")
plt.title("Rings of abalone")
# Out:
# Text(0.5, 1.0, 'Rings of abalone')

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.title("Sex of abalone")
# Out:
# Text(0.5, 1.0, 'Sex of abalone')

# %%
# 레이블 갯수 확인 (숫자)
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
#레이블을 숫자로 변환
from sklearn.preprocessing import StandardScaler, LabelEncoder

# LabelEncoder 객체 생성
label = LabelEncoder()

# 문자로 지정된 열의 데이터에 대해 LabelEncoder를 적용하여 변환
df['Sex'] = label.fit_transform(df['Sex'])

df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df_corr = df[[ 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']]

#상관 관계 행렬
# 0.3 이상인 경우 상관관계가 있고, 0.7이상이면 아주 높음

df_corr=df_corr.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
# Convert RingCount to Age by adding 1.5, accoring to codebook
df['Age'] = df['Rings'] + 1.5
df.drop('Rings', axis=1, inplace=True)

# %%
X=df.drop('Sex', axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
y=df['Sex']
y.value_counts()
# Out:
# Sex
# 2    1528
# 1    1342
# 0    1307
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값

scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

X_train
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.553972 -0.655933 -0.821100     -0.792792       -0.752632
# 1     0.872732  0.564402  0.231527      0.388113        0.784560
# 2     0.914694  1.072875  0.582403      0.800817        0.642561
# 3    -1.435172 -1.469490 -1.288935     -1.299477       -1.325134
# 4     1.502161  1.479653  1.284155      1.870374        1.566679
# ...        ...       ...       ...           ...             ...
# 3127  1.040580  1.174569  1.050238      1.603751        1.359316
# 3128  1.082542  0.920333 -0.002390      0.681297        0.800337
# 3129  0.578999  0.411860  0.114569      0.249183        0.450976
# 3130  0.830770  0.818638  0.582403      0.592422        0.514086
# 3131 -0.973591 -0.859323 -0.704142     -1.044091       -1.038883
#
#       Viscera weight  Shell weight       Age
# 0          -0.801600     -0.825276 -0.921055
# 1           0.054099     -0.469265 -0.610232
# 2           1.056228      0.807342  0.011413
# 3          -1.181402     -1.235229 -0.610232
# 4           2.191058      1.976066  0.633058
# ...              ...           ...       ...
# 3127        1.285024      1.695572  0.011413
# 3128        1.239265      0.314680  0.633058
# 3129        0.223408      0.088127  0.011413
# 3130        0.497964      0.555617 -0.299410
# 3131       -0.980061     -1.008676 -0.610232
#
# [3132 rows x 8 columns]

# %%
X_train.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Age'],
#       dtype='object')

# %%
y_train
# Out:
# 940     1
# 2688    2
# 1948    2
# 713     2
# 3743    0
#        ..
# 1033    2
# 3264    0
# 1653    2
# 2607    0
# 2732    1
# Name: Sex, Length: 3132, dtype: int32

# %%
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
print('{:.5f}'.format(accuracy_score(y_test, pred_svm)))
print(confusion_matrix(y_test, pred_svm))
print(classification_report(y_test,pred_svm))
# Out:
# --- SVM Classifier ---
# 0.56172
# [[ 69  46 201]
#  [ 12 287  60]
#  [ 60  79 231]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.22      0.30       316
#            1       0.70      0.80      0.74       359
#            2       0.47      0.62      0.54       370
#
#     accuracy                           0.56      1045
#    macro avg       0.55      0.55      0.53      1045
# weighted avg       0.55      0.56      0.54      1045

# %%
# Build a decision tree classifier and predict

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print ('{:.5f}'.format(accuracy_score(y_test, pred_dt)))
print (confusion_matrix(y_test, pred_dt))
print(classification_report(y_test,pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.47656
# [[120  56 140]
#  [ 61 220  78]
#  [151  61 158]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.38      0.37       316
#            1       0.65      0.61      0.63       359
#            2       0.42      0.43      0.42       370
#
#     accuracy                           0.48      1045
#    macro avg       0.48      0.47      0.48      1045
# weighted avg       0.48      0.48      0.48      1045

# %%
clf_nn = MLPClassifier(random_state=0)
clf_nn.fit(X_train, y_train)

pred_nn = clf_nn.predict(X_test)

print ("\n--- Neural Network Classifier ---")
print ('{:.5f}'.format(accuracy_score(y_test, pred_nn)))
print (confusion_matrix(y_test, pred_nn))
print(classification_report(y_test,pred_nn))
# Out:
# --- Neural Network Classifier ---
# 0.57225
# [[123  38 155]
#  [ 32 279  48]
#  [110  64 196]]
#               precision    recall  f1-score   support
#
#            0       0.46      0.39      0.42       316
#            1       0.73      0.78      0.75       359
#            2       0.49      0.53      0.51       370
#
#     accuracy                           0.57      1045
#    macro avg       0.56      0.57      0.56      1045
# weighted avg       0.57      0.57      0.57      1045
# C:\Anaconda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## ML-Regression 다른 특성 파악

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# 3             0.1140        0.1550  11.5
# 4             0.0395        0.0550   8.5
# ...              ...           ...   ...
# 4172          0.2390        0.2490  12.5
# 4173          0.2145        0.2605  11.5
# 4174          0.2875        0.3080  10.5
# 4175          0.2610        0.2960  11.5
# 4176          0.3765        0.4950  13.5
#
# [4177 rows x 9 columns]

# %%
X=df.drop('Length', axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#    Sex  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0    2     0.365   0.095        0.5140          0.2245          0.1010
# 1    2     0.265   0.090        0.2255          0.0995          0.0485
# 2    0     0.420   0.135        0.6770          0.2565          0.1415
# 3    2     0.365   0.125        0.5160          0.2155          0.1140
# 4    1     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
y=df['Length']
y
# Out:
# 0       0.455
# 1       0.350
# 2       0.530
# 3       0.440
# 4       0.330
#         ...
# 4172    0.565
# 4173    0.590
# 4174    0.600
# 4175    0.625
# 4176    0.710
# Name: Length, Length: 4177, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값

X_train
# Out:
#       Sex  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 940     1     0.345   0.105        0.4490          0.1960          0.0945
# 2688    2     0.465   0.150        1.0270          0.5370          0.1880
# 1948    2     0.515   0.165        1.2290          0.5055          0.2975
# 713     2     0.265   0.085        0.2010          0.0690          0.0530
# 3743    0     0.555   0.195        1.7525          0.7105          0.4215
# ...   ...       ...     ...           ...             ...             ...
# 1033    2     0.525   0.185        1.6220          0.6645          0.3225
# 3264    0     0.500   0.140        1.1705          0.5405          0.3175
# 1653    2     0.450   0.145        0.9590          0.4630          0.2065
# 2607    0     0.490   0.165        1.1270          0.4770          0.2365
# 2732    1     0.325   0.110        0.3260          0.1325          0.0750
#
#       Shell weight   Age
# 940         0.1265   8.5
# 2688        0.1760   9.5
# 1948        0.3535  11.5
# 713         0.0695   9.5
# 3743        0.5160  13.5
# ...            ...   ...
# 1033        0.4770  11.5
# 3264        0.2850  13.5
# 1653        0.2535  11.5
# 2607        0.3185  10.5
# 2732        0.1010   9.5
#
# [3132 rows x 8 columns]

# %%
# Scale X
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print('모델점수', model.score(X_test, y_test))

from sklearn.metrics import mean_squared_error

ly_preds = model.predict(X_test)
mse = np.sqrt(mean_squared_error(ly_preds, y_test))
print('평균제곱근오차', mse)
# Out:
# 모델점수 0.9774722017577516
# 평균제곱근오차 0.01840198809552233

# %% [markdown]
# ## DL 성별 예측

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# 3             0.1140        0.1550  11.5
# 4             0.0395        0.0550   8.5
# ...              ...           ...   ...
# 4172          0.2390        0.2490  12.5
# 4173          0.2145        0.2605  11.5
# 4174          0.2875        0.3080  10.5
# 4175          0.2610        0.2960  11.5
# 4176          0.3765        0.4950  13.5
#
# [4177 rows x 9 columns]

# %%
X=df.drop('Sex', axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
y=df['Sex']
y.value_counts()
# Out:
# Sex
# 2    1528
# 1    1342
# 0    1307
# Name: count, dtype: int64

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        ...,
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값
X_train
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 940    0.460     0.345   0.105        0.4490          0.1960          0.0945
# 2688   0.630     0.465   0.150        1.0270          0.5370          0.1880
# 1948   0.635     0.515   0.165        1.2290          0.5055          0.2975
# 713    0.355     0.265   0.085        0.2010          0.0690          0.0530
# 3743   0.705     0.555   0.195        1.7525          0.7105          0.4215
# ...      ...       ...     ...           ...             ...             ...
# 1033   0.650     0.525   0.185        1.6220          0.6645          0.3225
# 3264   0.655     0.500   0.140        1.1705          0.5405          0.3175
# 1653   0.595     0.450   0.145        0.9590          0.4630          0.2065
# 2607   0.625     0.490   0.165        1.1270          0.4770          0.2365
# 2732   0.410     0.325   0.110        0.3260          0.1325          0.0750
#
#       Shell weight   Age
# 940         0.1265   8.5
# 2688        0.1760   9.5
# 1948        0.3535  11.5
# 713         0.0695   9.5
# 3743        0.5160  13.5
# ...            ...   ...
# 1033        0.4770  11.5
# 3264        0.2850  13.5
# 1653        0.2535  11.5
# 2607        0.3185  10.5
# 2732        0.1010   9.5
#
# [3132 rows x 8 columns]

# %%
X_train.shape[1]
# Out:
# 8

# %%
y_train
# Out:
# array([[False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        ...,
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False]])

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras.optimizers import Adam

# Define the input layer
inputs = Input(shape=(X_train.shape[1],))

# Define the model architecture
x = Dense(12, activation='relu')(inputs)
x = Dense(15, activation='relu')(x)
x = Dense(6, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x)

# Create the model
model = Model(inputs=inputs, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.02), loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 8)]               0
#
#  dense_43 (Dense)            (None, 12)                108
#
#  dense_44 (Dense)            (None, 15)                195
#
#  dense_45 (Dense)            (None, 6)                 96
#
#  dense_46 (Dense)            (None, 3)                 21
#
# =================================================================
# Total params: 420 (1.64 KB)
# Trainable params: 420 (1.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1) # 배열에서 최댓값을 가지는 원소의 인덱스를 반환하는 함수
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/50
# 98/98 [==============================] - 2s 5ms/step - loss: 1.1126 - accuracy: 0.3576 - val_loss: 1.0990 - val_accuracy: 0.3541
# Epoch 2/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0979 - accuracy: 0.3697 - val_loss: 1.0975 - val_accuracy: 0.3541
# Epoch 3/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3697 - val_loss: 1.1004 - val_accuracy: 0.3541
# Epoch 4/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0965 - accuracy: 0.3697 - val_loss: 1.1062 - val_accuracy: 0.3541
# Epoch 5/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.0970 - val_accuracy: 0.3541
# Epoch 6/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0966 - accuracy: 0.3697 - val_loss: 1.0986 - val_accuracy: 0.3541
# Epoch 7/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0966 - accuracy: 0.3697 - val_loss: 1.0994 - val_accuracy: 0.3541
# Epoch 8/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.0998 - val_accuracy: 0.3541
# Epoch 9/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0969 - accuracy: 0.3630 - val_loss: 1.1006 - val_accuracy: 0.3541
# Epoch 10/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0966 - accuracy: 0.3633 - val_loss: 1.0985 - val_accuracy: 0.3541
# Epoch 11/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.0973 - val_accuracy: 0.3541
# Epoch 12/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.0980 - val_accuracy: 0.3541
# Epoch 13/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0970 - accuracy: 0.3697 - val_loss: 1.0989 - val_accuracy: 0.3541
# Epoch 14/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0974 - accuracy: 0.3697 - val_loss: 1.0966 - val_accuracy: 0.3541
# Epoch 15/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0970 - accuracy: 0.3617 - val_loss: 1.0966 - val_accuracy: 0.3541
# Epoch 16/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0975 - accuracy: 0.3697 - val_loss: 1.0980 - val_accuracy: 0.3541
# Epoch 17/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3586 - val_loss: 1.1000 - val_accuracy: 0.3541
# Epoch 18/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3697 - val_loss: 1.0974 - val_accuracy: 0.3541
# Epoch 19/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0973 - accuracy: 0.3697 - val_loss: 1.0969 - val_accuracy: 0.3541
# Epoch 20/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0970 - accuracy: 0.3697 - val_loss: 1.0972 - val_accuracy: 0.3541
# Epoch 21/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0971 - accuracy: 0.3697 - val_loss: 1.0981 - val_accuracy: 0.3541
# Epoch 22/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0962 - accuracy: 0.3697 - val_loss: 1.0999 - val_accuracy: 0.3541
# Epoch 23/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3697 - val_loss: 1.0999 - val_accuracy: 0.3541
# Epoch 24/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0960 - accuracy: 0.3697 - val_loss: 1.0972 - val_accuracy: 0.3435
# Epoch 25/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0976 - accuracy: 0.3611 - val_loss: 1.0981 - val_accuracy: 0.3541
# Epoch 26/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0966 - accuracy: 0.3697 - val_loss: 1.0996 - val_accuracy: 0.3541
# Epoch 27/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0967 - accuracy: 0.3637 - val_loss: 1.0984 - val_accuracy: 0.3541
# Epoch 28/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3697 - val_loss: 1.0989 - val_accuracy: 0.3541
# Epoch 29/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0966 - accuracy: 0.3697 - val_loss: 1.1008 - val_accuracy: 0.3541
# Epoch 30/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3633 - val_loss: 1.1041 - val_accuracy: 0.3541
# Epoch 31/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0971 - accuracy: 0.3586 - val_loss: 1.0965 - val_accuracy: 0.3541
# Epoch 32/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.1008 - val_accuracy: 0.3541
# Epoch 33/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0967 - accuracy: 0.3697 - val_loss: 1.0975 - val_accuracy: 0.3541
# Epoch 34/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0976 - accuracy: 0.3697 - val_loss: 1.0979 - val_accuracy: 0.3541
# Epoch 35/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0973 - accuracy: 0.3697 - val_loss: 1.1001 - val_accuracy: 0.3541
# Epoch 36/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0964 - accuracy: 0.3697 - val_loss: 1.1018 - val_accuracy: 0.3541
# Epoch 37/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0970 - accuracy: 0.3697 - val_loss: 1.1003 - val_accuracy: 0.3541
# Epoch 38/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0964 - accuracy: 0.3697 - val_loss: 1.0970 - val_accuracy: 0.3541
# Epoch 39/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3614 - val_loss: 1.1038 - val_accuracy: 0.3541
# Epoch 40/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0977 - accuracy: 0.3697 - val_loss: 1.0966 - val_accuracy: 0.3541
# Epoch 41/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.0977 - val_accuracy: 0.3541
# Epoch 42/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0967 - accuracy: 0.3697 - val_loss: 1.0975 - val_accuracy: 0.3541
# Epoch 43/50
# 98/98 [==============================] - 0s 4ms/step - loss: 1.0964 - accuracy: 0.3697 - val_loss: 1.1010 - val_accuracy: 0.3541
# Epoch 44/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0977 - accuracy: 0.3697 - val_loss: 1.0977 - val_accuracy: 0.3541
# Epoch 45/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0972 - accuracy: 0.3697 - val_loss: 1.0981 - val_accuracy: 0.3541
# Epoch 46/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3697 - val_loss: 1.1025 - val_accuracy: 0.3541
# Epoch 47/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0963 - accuracy: 0.3697 - val_loss: 1.0988 - val_accuracy: 0.3541
# Epoch 48/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0979 - accuracy: 0.3697 - val_loss: 1.0979 - val_accuracy: 0.3541
# Epoch 49/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0968 - accuracy: 0.3697 - val_loss: 1.0981 - val_accuracy: 0.3541
# Epoch 50/50
# 98/98 [==============================] - 0s 3ms/step - loss: 1.0959 - accuracy: 0.3669 - val_loss: 1.1022 - val_accuracy: 0.3541
# 33/33 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 훈련 손실(training loss)과 검증 손실(validation loss) 추출
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# 에포크(epoch) 범위 생성
epochs = range(1, len(loss) + 1)

# 훈련 손실(training loss)과 검증 손실(validation loss) 시각화
plt.plot(epochs, loss, 'y', label='Training loss')  # 훈련 손실을 노란색(yellow)으로 플롯
plt.plot(epochs, val_loss, 'r', label='Validation loss')  # 검증 손실을 빨간색(red)으로 플롯
plt.title('Training and validation loss')  # 그래프 제목 설정
plt.xlabel('Epochs')  # x축 레이블 설정
plt.ylabel('Loss')  # y축 레이블 설정
plt.legend()  # 범례(legend) 표시
plt.show()  # 그래프 출력

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       316
#            1       0.00      0.00      0.00       359
#            2       0.35      1.00      0.52       370
#
#     accuracy                           0.35      1045
#    macro avg       0.12      0.33      0.17      1045
# weighted avg       0.13      0.35      0.19      1045
#
# [[  0   0 316]
#  [  0   0 359]
#  [  0   0 370]]
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
