# %%
import numpy as numpy
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# 데이터 다운로드
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data( num_words=1000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 2s 0us/step

# %%
# 원-핫 인코딩으로 변환하는 함수
def one_hot_sequences(sequences, dimension=1000):
    results = numpy.zeros((len(sequences), dimension))
    for i, word_index in enumerate(sequences):
        results[i, word_index] = 1.
        return results

# %%
X_train = one_hot_sequences(X_train)
X_test = one_hot_sequences(X_test)

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
# 신경망 모델 구축
inputs = Input(shape=1000,)

x = Dense(32, activation='relu')(inputs)
x = Dense(24, activation='relu')(x)
x = Dense(16, activation='relu')(x)
x = layers.Dropout(0.3)(x) # 드롭아웃으로 노드 비활성화
prediction = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=prediction)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 신경망 훈련, 검증 데이터 전달, 조기종료 적용
early_stopping = EarlyStopping()
history = model.fit(X_train, y_train, epochs=20, batch_size=512, validation_data=(X_test, y_test), callbacks = [early_stopping], verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 3s - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.5000 - 3s/epoch - 60ms/step
# Epoch 2/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4946 - val_loss: 0.6932 - val_accuracy: 0.5000 - 388ms/epoch - 8ms/step

# %%
# 신경망 훈련, 검증 데이터 전달, 조기종료 적용 X
early_stopping = EarlyStopping()
history = model.fit(X_train, y_train, epochs=20, batch_size=512, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6931 - accuracy: 0.4970 - val_loss: 0.6932 - val_accuracy: 0.5000 - 594ms/epoch - 12ms/step
# Epoch 2/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4981 - val_loss: 0.6932 - val_accuracy: 0.5000 - 348ms/epoch - 7ms/step
# Epoch 3/20
# 49/49 - 0s - loss: 0.6932 - accuracy: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.5000 - 381ms/epoch - 8ms/step
# Epoch 4/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4979 - val_loss: 0.6932 - val_accuracy: 0.5000 - 319ms/epoch - 7ms/step
# Epoch 5/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.5000 - 396ms/epoch - 8ms/step
# Epoch 6/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4986 - val_loss: 0.6932 - val_accuracy: 0.5000 - 371ms/epoch - 8ms/step
# Epoch 7/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4950 - val_loss: 0.6932 - val_accuracy: 0.5000 - 343ms/epoch - 7ms/step
# Epoch 8/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4991 - val_loss: 0.6932 - val_accuracy: 0.5000 - 359ms/epoch - 7ms/step
# Epoch 9/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.5000 - 438ms/epoch - 9ms/step
# Epoch 10/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4952 - val_loss: 0.6932 - val_accuracy: 0.5000 - 335ms/epoch - 7ms/step
# Epoch 11/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4973 - val_loss: 0.6932 - val_accuracy: 0.5000 - 410ms/epoch - 8ms/step
# Epoch 12/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4970 - val_loss: 0.6932 - val_accuracy: 0.5000 - 361ms/epoch - 7ms/step
# Epoch 13/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4966 - val_loss: 0.6932 - val_accuracy: 0.5000 - 350ms/epoch - 7ms/step
# Epoch 14/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4966 - val_loss: 0.6932 - val_accuracy: 0.5000 - 413ms/epoch - 8ms/step
# Epoch 15/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4958 - val_loss: 0.6932 - val_accuracy: 0.5000 - 336ms/epoch - 7ms/step
# Epoch 16/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4968 - val_loss: 0.6932 - val_accuracy: 0.5000 - 353ms/epoch - 7ms/step
# Epoch 17/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4952 - val_loss: 0.6932 - val_accuracy: 0.5000 - 364ms/epoch - 7ms/step
# Epoch 18/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4965 - val_loss: 0.6932 - val_accuracy: 0.5000 - 359ms/epoch - 7ms/step
# Epoch 19/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000 - 374ms/epoch - 8ms/step
# Epoch 20/20
# 49/49 - 0s - loss: 0.6931 - accuracy: 0.4963 - val_loss: 0.6932 - val_accuracy: 0.5000 - 359ms/epoch - 7ms/step

# %%
# 훈련 데이터와 손실값의 검증 데이터의 손실값을 그래프에 출력, 조기종료 적용
history_dict = history.history
loss_values = history_dict['loss'] # 훈련 데이터 손실 값
val_loss_values = history_dict['val_loss'] # 검증 데이터 손실 값
acc = history_dict['accuracy'] # 정확도
epochs = range(1, len(acc) + 1) # 에포크 수

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Plot')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train error', 'val error'], loc='upper left')
plt.show()

# %%
# 훈련 데이터와 손실값의 검증 데이터의 손실값을 그래프에 출력, 조기종료 적용 X
history_dict = history.history
loss_values = history_dict['loss'] # 훈련 데이터 손실 값
val_loss_values = history_dict['val_loss'] # 검증 데이터 손실 값
acc = history_dict['accuracy'] # 정확도
epochs = range(1, len(acc) + 1) # 에포크 수

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Plot')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train error', 'val error'], loc='upper left')
plt.show()
