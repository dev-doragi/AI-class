# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
import pandas as pd

# 데이터 파일 경로 설정
file_path = "./seeds_dataset.txt"

# 데이터 파일 읽기
column_names = ['Area', 'Perimeter', 'Compactness', 'Length of kernel', 'Width of kernel', 'Asymmetry coefficient', 'Length of kernel groove', 'Class']
df = pd.read_csv(file_path, sep='\t', header=None, names=column_names)

df
# Out:
#       Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# 1                    1.018                    4.956      1
# 2                    2.699                    4.825      1
# 3                    2.259                    4.805      1
# 4                    1.355                    5.175      1
# ..                     ...                      ...    ...
# 205                  3.631                    4.870      3
# 206                  4.325                    5.003      3
# 207                  8.315                    5.056      3
# 208                  3.598                    5.044      3
# 209                  5.637                    5.063      3
#
# [210 rows x 8 columns]

# %%
X=df.drop('Class', axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#     Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    Asymmetry coefficient  Length of kernel groove
# 0                  2.221                    5.220
# 1                  1.018                    4.956
# 2                  2.699                    4.825
# 3                  2.259                    4.805
# 4                  1.355                    5.175

# %%
y=df['Class']
y.value_counts()
# Out:
# Class
# 1    70
# 2    70
# 3    70
# Name: count, dtype: int64

# %% [markdown]
# ## 기본 딥러닝 (DNN)

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값

scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

X_train
# Out:
#          Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0   -0.746116  -0.659724    -1.022187         -0.476551        -0.906322
# 1    0.622328   0.695258     0.184523          0.954009         0.571724
# 2   -0.432158  -0.523469     0.747049         -0.614490        -0.252674
# 3    1.277543   1.270557     0.719830          1.176491         1.129326
# 4    1.311669   1.414382    -0.037766          1.470167         0.915890
# ..        ...        ...          ...               ...              ...
# 152 -0.271767  -0.190400    -0.368930         -0.033812        -0.247338
# 153 -1.002059  -1.151756     0.402275         -1.095051        -0.794268
# 154  1.482298   1.444661     0.833243          1.381174         1.505507
# 155  0.062665   0.013982     0.801487         -0.120580         0.336944
# 156 -1.206814  -1.189605    -1.303450         -1.192943        -1.301179
#
#      Asymmetry coefficient  Length of kernel groove
# 0                -0.254136                -0.348533
# 1                -1.096600                 0.963359
# 2                -0.732597                -0.456165
# 3                -1.297567                 0.997883
# 4                 0.467881                 1.420288
# ..                     ...                      ...
# 152              -0.978814                -0.549582
# 153              -0.060489                -0.549582
# 154              -0.401866                 1.588844
# 155              -0.485714                -0.462258
# 156               0.413314                -0.817647
#
# [157 rows x 7 columns]

# %%
y_train
# Out:
# array([[False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True],
#        [False,  True, False],
#        [ True, False, False],
#        [False, False,  True]])

# %%
print(X_train.shape, y_train.shape)
# Out:
# (157, 7) (157, 3)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (53, 7) (53, 3)

# %%
# 신경망 모델 구축
inputs = Input(shape=(X_train.shape[1],))

x = Dense(32, activation='relu')(inputs)
x = Dense(24, activation='relu')(x)
x = Dense(16, activation='relu')(x)
x = layers.Dropout(0.3)(x) # 드롭아웃으로 노드 비활성화
prediction = Dense(3, activation='softmax')(x)

model = Model(inputs=inputs, outputs=prediction)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 신경망 훈련, 검증 데이터 전달, 조기종료 적용
early_stopping = EarlyStopping()
history = model.fit(X_train, y_train, epochs=40, batch_size=144, validation_data=(X_test, y_test), callbacks = [early_stopping], verbose=2)
# Out:
# Epoch 1/40
# 2/2 - 1s - loss: 1.1910 - accuracy: 0.3121 - val_loss: 1.1039 - val_accuracy: 0.4151 - 1s/epoch - 520ms/step
# Epoch 2/40
# 2/2 - 0s - loss: 1.1377 - accuracy: 0.3758 - val_loss: 1.0829 - val_accuracy: 0.4340 - 23ms/epoch - 11ms/step
# Epoch 3/40
# 2/2 - 0s - loss: 1.1149 - accuracy: 0.3694 - val_loss: 1.0611 - val_accuracy: 0.4717 - 21ms/epoch - 11ms/step
# Epoch 4/40
# 2/2 - 0s - loss: 1.1005 - accuracy: 0.3885 - val_loss: 1.0400 - val_accuracy: 0.5283 - 23ms/epoch - 11ms/step
# Epoch 5/40
# 2/2 - 0s - loss: 1.0715 - accuracy: 0.4204 - val_loss: 1.0187 - val_accuracy: 0.5283 - 22ms/epoch - 11ms/step
# Epoch 6/40
# 2/2 - 0s - loss: 1.0571 - accuracy: 0.4713 - val_loss: 0.9979 - val_accuracy: 0.5849 - 23ms/epoch - 11ms/step
# Epoch 7/40
# 2/2 - 0s - loss: 1.0208 - accuracy: 0.5096 - val_loss: 0.9780 - val_accuracy: 0.6038 - 22ms/epoch - 11ms/step
# Epoch 8/40
# 2/2 - 0s - loss: 0.9943 - accuracy: 0.4777 - val_loss: 0.9588 - val_accuracy: 0.6226 - 22ms/epoch - 11ms/step
# Epoch 9/40
# 2/2 - 0s - loss: 0.9994 - accuracy: 0.5223 - val_loss: 0.9405 - val_accuracy: 0.7358 - 23ms/epoch - 11ms/step
# Epoch 10/40
# 2/2 - 0s - loss: 0.9517 - accuracy: 0.5669 - val_loss: 0.9230 - val_accuracy: 0.7358 - 22ms/epoch - 11ms/step
# Epoch 11/40
# 2/2 - 0s - loss: 0.9418 - accuracy: 0.6178 - val_loss: 0.9065 - val_accuracy: 0.7547 - 23ms/epoch - 11ms/step
# Epoch 12/40
# 2/2 - 0s - loss: 0.9343 - accuracy: 0.5669 - val_loss: 0.8905 - val_accuracy: 0.7736 - 22ms/epoch - 11ms/step
# Epoch 13/40
# 2/2 - 0s - loss: 0.8973 - accuracy: 0.6369 - val_loss: 0.8747 - val_accuracy: 0.7925 - 23ms/epoch - 11ms/step
# Epoch 14/40
# 2/2 - 0s - loss: 0.9140 - accuracy: 0.5732 - val_loss: 0.8595 - val_accuracy: 0.8113 - 23ms/epoch - 12ms/step
# Epoch 15/40
# 2/2 - 0s - loss: 0.8797 - accuracy: 0.6369 - val_loss: 0.8448 - val_accuracy: 0.8113 - 22ms/epoch - 11ms/step
# Epoch 16/40
# 2/2 - 0s - loss: 0.8641 - accuracy: 0.6115 - val_loss: 0.8304 - val_accuracy: 0.8302 - 21ms/epoch - 11ms/step
# Epoch 17/40
# 2/2 - 0s - loss: 0.8571 - accuracy: 0.6624 - val_loss: 0.8160 - val_accuracy: 0.8302 - 22ms/epoch - 11ms/step
# Epoch 18/40
# 2/2 - 0s - loss: 0.8355 - accuracy: 0.6688 - val_loss: 0.8019 - val_accuracy: 0.8302 - 21ms/epoch - 11ms/step
# Epoch 19/40
# 2/2 - 0s - loss: 0.8008 - accuracy: 0.7134 - val_loss: 0.7883 - val_accuracy: 0.8302 - 22ms/epoch - 11ms/step
# Epoch 20/40
# 2/2 - 0s - loss: 0.8129 - accuracy: 0.6943 - val_loss: 0.7753 - val_accuracy: 0.8491 - 22ms/epoch - 11ms/step
# Epoch 21/40
# 2/2 - 0s - loss: 0.8086 - accuracy: 0.6497 - val_loss: 0.7625 - val_accuracy: 0.8491 - 22ms/epoch - 11ms/step
# Epoch 22/40
# 2/2 - 0s - loss: 0.7852 - accuracy: 0.6943 - val_loss: 0.7505 - val_accuracy: 0.8491 - 22ms/epoch - 11ms/step
# Epoch 23/40
# 2/2 - 0s - loss: 0.7722 - accuracy: 0.7516 - val_loss: 0.7392 - val_accuracy: 0.8491 - 22ms/epoch - 11ms/step
# Epoch 24/40
# 2/2 - 0s - loss: 0.7651 - accuracy: 0.7134 - val_loss: 0.7281 - val_accuracy: 0.8491 - 21ms/epoch - 11ms/step
# Epoch 25/40
# 2/2 - 0s - loss: 0.7625 - accuracy: 0.7261 - val_loss: 0.7174 - val_accuracy: 0.8491 - 21ms/epoch - 11ms/step
# Epoch 26/40
# 2/2 - 0s - loss: 0.7501 - accuracy: 0.7325 - val_loss: 0.7067 - val_accuracy: 0.8491 - 23ms/epoch - 11ms/step
# Epoch 27/40
# 2/2 - 0s - loss: 0.7742 - accuracy: 0.7261 - val_loss: 0.6958 - val_accuracy: 0.8679 - 21ms/epoch - 11ms/step
# Epoch 28/40
# 2/2 - 0s - loss: 0.7241 - accuracy: 0.7962 - val_loss: 0.6851 - val_accuracy: 0.8679 - 22ms/epoch - 11ms/step
# Epoch 29/40
# 2/2 - 0s - loss: 0.7214 - accuracy: 0.7771 - val_loss: 0.6745 - val_accuracy: 0.8679 - 21ms/epoch - 11ms/step
# Epoch 30/40
# 2/2 - 0s - loss: 0.7157 - accuracy: 0.7898 - val_loss: 0.6637 - val_accuracy: 0.8679 - 21ms/epoch - 11ms/step
# Epoch 31/40
# 2/2 - 0s - loss: 0.7047 - accuracy: 0.7516 - val_loss: 0.6526 - val_accuracy: 0.8679 - 21ms/epoch - 10ms/step
# Epoch 32/40
# 2/2 - 0s - loss: 0.6886 - accuracy: 0.8344 - val_loss: 0.6415 - val_accuracy: 0.9057 - 22ms/epoch - 11ms/step
# Epoch 33/40
# 2/2 - 0s - loss: 0.6764 - accuracy: 0.8089 - val_loss: 0.6304 - val_accuracy: 0.9057 - 22ms/epoch - 11ms/step
# Epoch 34/40
# 2/2 - 0s - loss: 0.6776 - accuracy: 0.8025 - val_loss: 0.6198 - val_accuracy: 0.9245 - 22ms/epoch - 11ms/step
# Epoch 35/40
# 2/2 - 0s - loss: 0.6700 - accuracy: 0.8089 - val_loss: 0.6092 - val_accuracy: 0.9245 - 21ms/epoch - 10ms/step
# Epoch 36/40
# 2/2 - 0s - loss: 0.6511 - accuracy: 0.8089 - val_loss: 0.5981 - val_accuracy: 0.9245 - 21ms/epoch - 10ms/step
# Epoch 37/40
# 2/2 - 0s - loss: 0.6510 - accuracy: 0.8662 - val_loss: 0.5866 - val_accuracy: 0.9245 - 21ms/epoch - 11ms/step
# Epoch 38/40
# 2/2 - 0s - loss: 0.6511 - accuracy: 0.8089 - val_loss: 0.5752 - val_accuracy: 0.9245 - 21ms/epoch - 11ms/step
# Epoch 39/40
# 2/2 - 0s - loss: 0.6403 - accuracy: 0.7962 - val_loss: 0.5642 - val_accuracy: 0.9245 - 21ms/epoch - 11ms/step
# Epoch 40/40
# 2/2 - 0s - loss: 0.6206 - accuracy: 0.8153 - val_loss: 0.5530 - val_accuracy: 0.9245 - 22ms/epoch - 11ms/step

# %%
# 훈련 데이터와 손실값의 검증 데이터의 손실값을 그래프에 출력, 조기종료 적용
history_dict = history.history
loss_values = history_dict['loss'] # 훈련 데이터 손실 값
val_loss_values = history_dict['val_loss'] # 검증 데이터 손실 값
acc = history_dict['accuracy'] # 정확도
epochs = range(1, len(acc) + 1) # 에포크 수

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Plot')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train error', 'val error'], loc='upper left')
plt.show()

# %% [markdown]
# ## CNN

# %%
import pandas as pd

# 데이터 파일 경로 설정
file_path = "./seeds_dataset.txt"

# 데이터 파일 읽기
column_names = ['Area', 'Perimeter', 'Compactness', 'Length of kernel', 'Width of kernel', 'Asymmetry coefficient', 'Length of kernel groove', 'Class']
df = pd.read_csv(file_path, sep='\t', header=None, names=column_names)

df
# Out:
#       Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# 1                    1.018                    4.956      1
# 2                    2.699                    4.825      1
# 3                    2.259                    4.805      1
# 4                    1.355                    5.175      1
# ..                     ...                      ...    ...
# 205                  3.631                    4.870      3
# 206                  4.325                    5.003      3
# 207                  8.315                    5.056      3
# 208                  3.598                    5.044      3
# 209                  5.637                    5.063      3
#
# [210 rows x 8 columns]

# %%
X=df.drop('Class', axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#     Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    Asymmetry coefficient  Length of kernel groove
# 0                  2.221                    5.220
# 1                  1.018                    4.956
# 2                  2.699                    4.825
# 3                  2.259                    4.805
# 4                  1.355                    5.175

# %%
y=df['Class']
y.value_counts()
# Out:
# Class
# 1    70
# 2    70
# 3    70
# Name: count, dtype: int64

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값

y_train.shape
X_test.shape
# Out:
# (53, 7)

# %%
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
y_train.shape
# Out:
# (157, 3)

# %%
y_train_array = np.array(y_train)
train_set = np.c_[X_train, y_train_array]

y_train_array.shape
# Out:
# (157, 3)

# %%
# Merge train and test X/y data to apply sequence transformation function
y_train_array = np.array(y_train)
train_set = np.c_[X_train, y_train_array]

y_test_array = np.array(y_test)
test_set = np.c_[X_test, y_test_array]

# Apply sequence transformation using time step of 25 for both train and test data
# All sensing modalities are recorded at a sampling rate of 50 Hz, which is considered sufficient for capturing human activity.

X_train, y_train = split_sequences(train_set, 5)
print(X_train.shape, y_train.shape)

X_test, y_test = split_sequences(test_set, 5)
print(X_test.shape, y_test.shape)
# Out:
# (153, 5, 9) (153,)
# (49, 5, 9) (49,)

# %%
y_train_onehot = pd.get_dummies(y_train).values
y_test_onehot = pd.get_dummies(y_test).values

# %%
from tensorflow.keras.layers import Conv1D, Conv2D, Conv3D
from tensorflow.keras.layers import Input
from keras.layers import Dense, Flatten, Dropout

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_onehot.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 5 9 3

# %%
X_train.shape[2]
# Out:
# 7

# %%
# 신경망 모델 구축
inputs = Input(shape=(5, n_features,))

x = Conv1D(32, 2, activation='relu')(inputs)
x = Dense(64, activation='relu')(x)
x = Flatten()(x)
prediction = Dense(n_outputs, activation='softmax')(x)

model = Model(inputs=inputs, outputs=prediction)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
y_train.shape
# Out:
# (153,)

# %%
# 신경망 훈련, 검증 데이터 전달, 조기종료 적용
model.fit(X_train, y_train, epochs=20, batch_size=144, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 # 신경망 훈련, 검증 데이터 전달, 조기종료 적용
# ----> 2 model.fit(X_train, y_train, epochs=20, batch_size=144, validation_data=(X_test, y_test), verbose=2)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filemwggagkb.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\engine\training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\engine\training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\engine\training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\engine\training.py", line 1151, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\engine\training.py", line 1209, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\engine\compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\backend.py", line 5573, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 3) are incompatible
