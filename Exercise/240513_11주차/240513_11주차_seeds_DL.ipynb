# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Out:
# WARNING:tensorflow:From C:\Anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
import pandas as pd

# 데이터 파일 경로 설정
file_path = "./seeds_dataset.txt"

# 데이터 파일 읽기
column_names = ['Area', 'Perimeter', 'Compactness', 'Length of kernel', 'Width of kernel', 'Asymmetry coefficient', 'Length of kernel groove', 'Class']
df = pd.read_csv(file_path, sep='\t', header=None, names=column_names)

df
# Out:
#       Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# ..     ...        ...          ...               ...              ...
# 205  12.19      13.20       0.8783             5.137            2.981
# 206  11.23      12.88       0.8511             5.140            2.795
# 207  13.20      13.66       0.8883             5.236            3.232
# 208  11.84      13.21       0.8521             5.175            2.836
# 209  12.30      13.34       0.8684             5.243            2.974
#
#      Asymmetry coefficient  Length of kernel groove  Class
# 0                    2.221                    5.220      1
# 1                    1.018                    4.956      1
# 2                    2.699                    4.825      1
# 3                    2.259                    4.805      1
# 4                    1.355                    5.175      1
# ..                     ...                      ...    ...
# 205                  3.631                    4.870      3
# 206                  4.325                    5.003      3
# 207                  8.315                    5.056      3
# 208                  3.598                    5.044      3
# 209                  5.637                    5.063      3
#
# [210 rows x 8 columns]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Area                       0
# Perimeter                  0
# Compactness                0
# Length of kernel           0
# Width of kernel            0
# Asymmetry coefficient      0
# Length of kernel groove    0
# Class                      0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Area                       0
# Perimeter                  0
# Compactness                0
# Length of kernel           0
# Width of kernel            0
# Asymmetry coefficient      0
# Length of kernel groove    0
# Class                      0
# dtype: int64

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="Class")
plt.xlabel("class")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df.columns
# Out:
# Index(['Area', 'Perimeter', 'Compactness', 'Length of kernel',
#        'Width of kernel', 'Asymmetry coefficient', 'Length of kernel groove',
#        'Class'],
#       dtype='object')

# %%
X=df.drop('Class', axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#     Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    Asymmetry coefficient  Length of kernel groove
# 0                  2.221                    5.220
# 1                  1.018                    4.956
# 2                  2.699                    4.825
# 3                  2.259                    4.805
# 4                  1.355                    5.175

# %%
y=df['Class']
y.value_counts()
# Out:
# Class
# 1    70
# 2    70
# 3    70
# Name: count, dtype: int64

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값

scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

X_train
# Out:
#          Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0   -0.746116  -0.659724    -1.022187         -0.476551        -0.906322
# 1    0.622328   0.695258     0.184523          0.954009         0.571724
# 2   -0.432158  -0.523469     0.747049         -0.614490        -0.252674
# 3    1.277543   1.270557     0.719830          1.176491         1.129326
# 4    1.311669   1.414382    -0.037766          1.470167         0.915890
# ..        ...        ...          ...               ...              ...
# 152 -0.271767  -0.190400    -0.368930         -0.033812        -0.247338
# 153 -1.002059  -1.151756     0.402275         -1.095051        -0.794268
# 154  1.482298   1.444661     0.833243          1.381174         1.505507
# 155  0.062665   0.013982     0.801487         -0.120580         0.336944
# 156 -1.206814  -1.189605    -1.303450         -1.192943        -1.301179
#
#      Asymmetry coefficient  Length of kernel groove
# 0                -0.254136                -0.348533
# 1                -1.096600                 0.963359
# 2                -0.732597                -0.456165
# 3                -1.297567                 0.997883
# 4                 0.467881                 1.420288
# ..                     ...                      ...
# 152              -0.978814                -0.549582
# 153              -0.060489                -0.549582
# 154              -0.401866                 1.588844
# 155              -0.485714                -0.462258
# 156               0.413314                -0.817647
#
# [157 rows x 7 columns]

# %%
# 신경망 모델 구축
inputs = Input(shape=(X_train.shape[1],))

x = Dense(32, activation='relu')(inputs)
x = Dense(24, activation='relu')(x)
x = Dense(16, activation='relu')(x)
x = layers.Dropout(0.3)(x) # 드롭아웃으로 노드 비활성화
prediction = Dense(3, activation='softmax')(x)

model = Model(inputs=inputs, outputs=prediction)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 신경망 훈련, 검증 데이터 전달, 조기종료 적용
early_stopping = EarlyStopping()
history = model.fit(X_train, y_train, epochs=20, batch_size=144, validation_data=(X_test, y_test), callbacks = [early_stopping], verbose=2)
# Out:
# Epoch 1/20
# 2/2 - 0s - loss: 0.1094 - accuracy: 0.9554 - val_loss: 0.2212 - val_accuracy: 0.9245 - 111ms/epoch - 56ms/step
# Epoch 2/20
# 2/2 - 0s - loss: 0.1218 - accuracy: 0.9554 - val_loss: 0.2186 - val_accuracy: 0.9245 - 41ms/epoch - 21ms/step
# Epoch 3/20
# 2/2 - 0s - loss: 0.1002 - accuracy: 0.9618 - val_loss: 0.2172 - val_accuracy: 0.9245 - 42ms/epoch - 21ms/step
# Epoch 4/20
# 2/2 - 0s - loss: 0.1486 - accuracy: 0.9427 - val_loss: 0.2163 - val_accuracy: 0.9434 - 51ms/epoch - 25ms/step
# Epoch 5/20
# 2/2 - 0s - loss: 0.1260 - accuracy: 0.9427 - val_loss: 0.2152 - val_accuracy: 0.9434 - 64ms/epoch - 32ms/step
# Epoch 6/20
# 2/2 - 0s - loss: 0.1051 - accuracy: 0.9554 - val_loss: 0.2142 - val_accuracy: 0.9434 - 70ms/epoch - 35ms/step
# Epoch 7/20
# 2/2 - 0s - loss: 0.1212 - accuracy: 0.9618 - val_loss: 0.2144 - val_accuracy: 0.9245 - 58ms/epoch - 29ms/step

# %%
# 훈련 데이터와 손실값의 검증 데이터의 손실값을 그래프에 출력, 조기종료 적용
history_dict = history.history
loss_values = history_dict['loss'] # 훈련 데이터 손실 값
val_loss_values = history_dict['val_loss'] # 검증 데이터 손실 값
acc = history_dict['accuracy'] # 정확도
epochs = range(1, len(acc) + 1) # 에포크 수

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Plot')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train error', 'val error'], loc='upper left')
plt.show()
